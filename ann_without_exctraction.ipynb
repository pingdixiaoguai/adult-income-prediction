# %%
# 导包
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from keras import models
from keras import layers
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from plot_confusion_matrix import plot_confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# 读取数据
# 根据题意，先把header设置好
headers = ['age', 'workclass', 'fnlwgt',
           'education', 'education_num', 'marital_status',
           'occupation', 'relationship', 'race',
           'sex', 'capital_gain', 'capital_loss',
           'hours_per_week', 'native_country', 'income']

# 读取训练集进入内存
train_data = pd.read_csv("data/adult_train.csv",names=headers)

# 对于测试集，他的第一行是一个分隔，不读入
test_data = pd.read_csv("data/adult_test.csv",names=headers,skiprows=[0])
test_data['income']= test_data['income'].apply(lambda x: x[0:-1])

# %%
train_data['source']='train'
test_data['source']='test'

# %%
# 合并数据一起进行预处理
data= pd.concat([train_data, test_data],axis=0,ignore_index=True)
train_data = train_data.replace('[?]', np.NaN, regex=True)
train_data.dropna(inplace=True)

# %%
# 对缺失数据进行处理，删除
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# source            0
# dtype: int64

# %%
# 开始处理离散数据
# income我们需要将其映射一下
# 先将>=50K的映射成1，<=50K的设置为0
le= LabelEncoder()
data['income']= le.fit_transform(data['income'])
data['income'].value_counts()
# Out:
# 0    37155
# 1    11687
# Name: income, dtype: int64

# %%
# 取出所有的离散量属性,这些属性先不用看我们自定义的数据来源那一项
discrete = [x for x in data.columns if data[x].dtype=='object']
discrete.remove('source')
discrete
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country']

# %%
# 看看这些离散量属性的取值分布
for i in discrete:
    print(train_data[i].value_counts())
# Out:
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: workclass, dtype: int64
#  HS-grad         9840
#  Some-college    6678
#  Bachelors       5044
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: education, dtype: int64
#  Married-civ-spouse       14065
#  Never-married             9726
#  Divorced                  4214
#  Separated                  939
#  Widowed                    827
#  Married-spouse-absent      370
#  Married-AF-spouse           21
# Name: marital_status, dtype: int64
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64
#  Husband           12463
#  Not-in-family      7726
#  Own-child          4466
#  Unmarried          3212
#  Wife               1406
#  Other-relative      889
# Name: relationship, dtype: int64
#  White                 25933
#  Black                  2817
#  Asian-Pac-Islander      895
#  Amer-Indian-Eskimo      286
#  Other                   231
# Name: race, dtype: int64
#  Male      20380
#  Female     9782
# Name: sex, dtype: int64
#  United-States                 27504
#  Mexico                          610
#  Philippines                     188
#  Germany                         128
#  Puerto-Rico                     109
#  Canada                          107
#  India                           100
#  El-Salvador                     100
#  Cuba                             92
#  England                          86
#  Jamaica                          80
#  South                            71
#  Italy                            68
#  China                            68
#  Dominican-Republic               67
#  Vietnam                          64
#  Guatemala                        63
#  Japan                            59
#  Poland                           56
#  Columbia                         56
#  Iran                             42
#  Haiti                            42
#  Taiwan                           42
#  Portugal                         34
#  Nicaragua                        33
#  Peru                             30
#  Greece                           29
#  France                           27
#  Ecuador                          27
#  Ireland                          24
#  Hong                             19
#  Cambodia                         18
#  Trinadad&Tobago                  18
#  Laos                             17
#  Thailand                         17
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         12
#  Scotland                         11
#  Holand-Netherlands                1
# Name: native_country, dtype: int64

# %%
# 看看education_num这个连续量
train_data['education'].value_counts()
# Out:
#  HS-grad         9840
#  Some-college    6678
#  Bachelors       5044
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: education, dtype: int64

# %%
# 发现跟education一样的，重复了，因为eudcation是离散的，不好处理。去掉这个属性
data = data.drop(columns=['education'])

# %%
# 看看相关系数矩阵,检查一下连续变量。发现序号属性不太影响最后的收入
data.corr()
# Out:
#                      age    fnlwgt  education_num  capital_gain  capital_loss  \
# age             1.000000 -0.076628       0.030940      0.077229      0.056944
# fnlwgt         -0.076628  1.000000      -0.038761     -0.003706     -0.004366
# education_num   0.030940 -0.038761       1.000000      0.125146      0.080972
# capital_gain    0.077229 -0.003706       0.125146      1.000000     -0.031441
# capital_loss    0.056944 -0.004366       0.080972     -0.031441      1.000000
# hours_per_week  0.071558 -0.013519       0.143689      0.082157      0.054467
# income          0.230369 -0.006339       0.332613      0.223013      0.147554
#
#                 hours_per_week    income
# age                   0.071558  0.230369
# fnlwgt               -0.013519 -0.006339
# education_num         0.143689  0.332613
# capital_gain          0.082157  0.223013
# capital_loss          0.054467  0.147554
# hours_per_week        1.000000  0.227687
# income                0.227687  1.000000

# %%
# 把序号属性删掉
data = data.drop(columns=['fnlwgt'])

# %%
discrete2 = [x for x in data.columns if data[x].dtype=='object']
discrete2.remove('source')
discrete2
# Out:
# ['workclass',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country']

# %%
# 进行哑编码
data = pd.get_dummies(data, columns=discrete2, drop_first=True)

# %%
# 看看编码后的结果
data.columns
# Out:
# Index(['age', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week', 'income', 'source', 'workclass_ Federal-gov',
#        'workclass_ Local-gov', 'workclass_ Never-worked', 'workclass_ Private',
#        'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc',
#        'workclass_ State-gov', 'workclass_ Without-pay',
#        'marital_status_ Married-AF-spouse',
#        'marital_status_ Married-civ-spouse',
#        'marital_status_ Married-spouse-absent',
#        'marital_status_ Never-married', 'marital_status_ Separated',
#        'marital_status_ Widowed', 'occupation_ Adm-clerical',
#        'occupation_ Armed-Forces', 'occupation_ Craft-repair',
#        'occupation_ Exec-managerial', 'occupation_ Farming-fishing',
#        'occupation_ Handlers-cleaners', 'occupation_ Machine-op-inspct',
#        'occupation_ Other-service', 'occupation_ Priv-house-serv',
#        'occupation_ Prof-specialty', 'occupation_ Protective-serv',
#        'occupation_ Sales', 'occupation_ Tech-support',
#        'occupation_ Transport-moving', 'relationship_ Not-in-family',
#        'relationship_ Other-relative', 'relationship_ Own-child',
#        'relationship_ Unmarried', 'relationship_ Wife',
#        'race_ Asian-Pac-Islander', 'race_ Black', 'race_ Other', 'race_ White',
#        'sex_ Male', 'native_country_ Cambodia', 'native_country_ Canada',
#        'native_country_ China', 'native_country_ Columbia',
#        'native_country_ Cuba', 'native_country_ Dominican-Republic',
#        'native_country_ Ecuador', 'native_country_ El-Salvador',
#        'native_country_ England', 'native_country_ France',
#        'native_country_ Germany', 'native_country_ Greece',
#        'native_country_ Guatemala', 'native_country_ Haiti',
#        'native_country_ Holand-Netherlands', 'native_country_ Honduras',
#        'native_country_ Hong', 'native_country_ Hungary',
#        'native_country_ India', 'native_country_ Iran',
#        'native_country_ Ireland', 'native_country_ Italy',
#        'native_country_ Jamaica', 'native_country_ Japan',
#        'native_country_ Laos', 'native_country_ Mexico',
#        'native_country_ Nicaragua',
#        'native_country_ Outlying-US(Guam-USVI-etc)', 'native_country_ Peru',
#        'native_country_ Philippines', 'native_country_ Poland',
#        'native_country_ Portugal', 'native_country_ Puerto-Rico',
#        'native_country_ Scotland', 'native_country_ South',
#        'native_country_ Taiwan', 'native_country_ Thailand',
#        'native_country_ Trinadad&Tobago', 'native_country_ United-States',
#        'native_country_ Vietnam', 'native_country_ Yugoslavia'],
#       dtype='object')

# %%
# 将非2值类型的数据进行标准化
num = [x for x in data.columns if data[x].dtype=='int64']
num
# Out:
# ['age', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']

# %%
scaler = StandardScaler()
data.loc[:, num] = scaler.fit_transform(data.loc[:, num])

# %%
train_data = data.loc[data['source']=='train',:]
test_data = data.loc[data['source']=='test',:]

# %%
# 把要预测的值income单独拿出来看看
y_train = np.array(train_data.income)
x_train = np.array(train_data.drop(['income','source'], axis=1))

y_test = np.array(test_data.income)
x_test = np.array(test_data.drop(['income','source'],axis=1))

x_train, x_eval, y_train, y_eval = train_test_split(x_train, y_train, test_size=0.2)

# %%
# 搭建一个神经网络
def build_model():
    """
    在此定义一个神经网络模型
    """
    model = models.Sequential()
    model.add(layers.Dense(units=40, activation='relu', input_dim=84))
    model.add((layers.Dense(units=20, activation='relu')))
    model.add((layers.Dense(units=10, activation='relu')))
    model.add((layers.Dense(units=1, activation='relu')))
    model.compile(optimizer='Adadelta',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# 使用模型,保存记录
model = build_model()
history = model.fit(x_train, y_train, epochs=100, batch_size=16, validation_data=(x_eval, y_eval))
# Out:
# Train on 26048 samples, validate on 6513 samples
# Epoch 1/100
# 26048/26048 [==============================] - 2s 84us/step - loss: 0.4439 - accuracy: 0.8273 - val_loss: 0.4556 - val_accuracy: 0.8334
# Epoch 2/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.4193 - accuracy: 0.8314 - val_loss: 0.4162 - val_accuracy: 0.8316
# Epoch 3/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.4205 - accuracy: 0.8323 - val_loss: 0.4408 - val_accuracy: 0.8339
# Epoch 4/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.4097 - accuracy: 0.8318 - val_loss: 0.4271 - val_accuracy: 0.8323
# Epoch 5/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.4063 - accuracy: 0.8331 - val_loss: 0.4095 - val_accuracy: 0.8349
# Epoch 6/100
# 26048/26048 [==============================] - 2s 74us/step - loss: 0.4039 - accuracy: 0.8347 - val_loss: 0.4146 - val_accuracy: 0.8323
# Epoch 7/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.4076 - accuracy: 0.8343 - val_loss: 0.4137 - val_accuracy: 0.8328
# Epoch 8/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.4039 - accuracy: 0.8330 - val_loss: 0.4207 - val_accuracy: 0.8322
# Epoch 9/100
# 26048/26048 [==============================] - 2s 75us/step - loss: 0.4232 - accuracy: 0.8324 - val_loss: 0.4029 - val_accuracy: 0.8333
# Epoch 10/100
# 26048/26048 [==============================] - 2s 74us/step - loss: 0.4194 - accuracy: 0.8331 - val_loss: 0.4462 - val_accuracy: 0.8287
# Epoch 11/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.4179 - accuracy: 0.8316 - val_loss: 0.4292 - val_accuracy: 0.8253
# Epoch 12/100
#  - ETA: 1s - loss: 0.3899 - accuracy: 0.8187
# Epoch 13/100
# 26048/26048 [==============================] - 2s 81us/step - loss: 0.4245 - accuracy: 0.8312 - val_loss: 0.4265 - val_accuracy: 0.8282
# Epoch 14/100
# 26048/26048 [==============================] - 2s 88us/step - loss: 0.4349 - accuracy: 0.8287 - val_loss: 0.4759 - val_accuracy: 0.8299
# Epoch 15/100
# 26048/26048 [==============================] - 2s 81us/step - loss: 0.4372 - accuracy: 0.8320 - val_loss: 0.5099 - val_accuracy: 0.8197
# Epoch 16/100
# 26048/26048 [==============================] - 2s 78us/step - loss: 0.4459 - accuracy: 0.8294 - val_loss: 0.5155 - val_accuracy: 0.8303
# Epoch 17/100
# 26048/26048 [==============================] - 2s 78us/step - loss: 0.4369 - accuracy: 0.8294 - val_loss: 0.5041 - val_accuracy: 0.8217
# Epoch 18/100
# 26048/26048 [==============================] - 2s 76us/step - loss: 0.4428 - accuracy: 0.8250 - val_loss: 0.4894 - val_accuracy: 0.8230
# Epoch 19/100
# 26048/26048 [==============================] - 2s 80us/step - loss: 0.4534 - accuracy: 0.8254 - val_loss: 0.5127 - val_accuracy: 0.8240
# Epoch 20/100
# 26048/26048 [==============================] - 2s 78us/step - loss: 0.4555 - accuracy: 0.8251 - val_loss: 0.4631 - val_accuracy: 0.8210
# Epoch 21/100
# 26048/26048 [==============================] - 2s 80us/step - loss: 0.4535 - accuracy: 0.8240 - val_loss: 0.5390 - val_accuracy: 0.8219
# Epoch 22/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.4621 - accuracy: 0.8224 - val_loss: 0.5245 - val_accuracy: 0.8165
# Epoch 23/100
# 26048/26048 [==============================] - 2s 75us/step - loss: 0.4555 - accuracy: 0.8194 - val_loss: 0.5401 - val_accuracy: 0.8153
# Epoch 24/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.4655 - accuracy: 0.8195 - val_loss: 0.5082 - val_accuracy: 0.8213
# Epoch 25/100
# 26048/26048 [==============================] - 2s 76us/step - loss: 0.4586 - accuracy: 0.8183 - val_loss: 0.5553 - val_accuracy: 0.8128
# Epoch 26/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.4574 - accuracy: 0.8177 - val_loss: 0.5288 - val_accuracy: 0.8156
# Epoch 27/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.4835 - accuracy: 0.8186 - val_loss: 0.5083 - val_accuracy: 0.8119
# Epoch 28/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.4710 - accuracy: 0.8178 - val_loss: 0.4948 - val_accuracy: 0.8079
# Epoch 29/100
# 26048/26048 [==============================] - 2s 74us/step - loss: 0.4668 - accuracy: 0.8148 - val_loss: 0.5648 - val_accuracy: 0.8179
# Epoch 30/100
# 26048/26048 [==============================] - 2s 74us/step - loss: 0.4851 - accuracy: 0.8141 - val_loss: 0.5475 - val_accuracy: 0.8075
# Epoch 31/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.4991 - accuracy: 0.8142 - val_loss: 0.5652 - val_accuracy: 0.8104
# Epoch 32/100
# 26048/26048 [==============================] - 2s 75us/step - loss: 0.5080 - accuracy: 0.8138 - val_loss: 0.5497 - val_accuracy: 0.8099
# Epoch 33/100
# 26048/26048 [==============================] - 2s 74us/step - loss: 0.4960 - accuracy: 0.8142 - val_loss: 0.5868 - val_accuracy: 0.8118
# Epoch 34/100
# 26048/26048 [==============================] - 2s 75us/step - loss: 0.5024 - accuracy: 0.8123 - val_loss: 0.5449 - val_accuracy: 0.8039
# Epoch 35/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5145 - accuracy: 0.8110 - val_loss: 0.5964 - val_accuracy: 0.7992
# Epoch 36/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5237 - accuracy: 0.8128 - val_loss: 0.6054 - val_accuracy: 0.7987
# Epoch 37/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.5181 - accuracy: 0.8117 - val_loss: 0.6632 - val_accuracy: 0.8032
# Epoch 38/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5141 - accuracy: 0.8115 - val_loss: 0.5951 - val_accuracy: 0.8047
# Epoch 39/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5234 - accuracy: 0.8102 - val_loss: 0.6129 - val_accuracy: 0.8055
# Epoch 40/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5208 - accuracy: 0.8079 - val_loss: 0.5775 - val_accuracy: 0.7987
# Epoch 41/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5351 - accuracy: 0.8092 - val_loss: 0.6326 - val_accuracy: 0.7998
# Epoch 42/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5271 - accuracy: 0.8068 - val_loss: 0.5958 - val_accuracy: 0.8036
# Epoch 43/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5282 - accuracy: 0.8100 - val_loss: 0.6257 - val_accuracy: 0.8002
# Epoch 44/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5273 - accuracy: 0.8094 - val_loss: 0.6429 - val_accuracy: 0.8029
# Epoch 45/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.5327 - accuracy: 0.8097 - val_loss: 0.6294 - val_accuracy: 0.8013
# Epoch 46/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5312 - accuracy: 0.8091 - val_loss: 0.6156 - val_accuracy: 0.7981
# Epoch 47/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.5427 - accuracy: 0.8090 - val_loss: 0.6812 - val_accuracy: 0.7947
# Epoch 48/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5530 - accuracy: 0.8054 - val_loss: 0.6800 - val_accuracy: 0.8013
# Epoch 49/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5477 - accuracy: 0.8070 - val_loss: 0.5951 - val_accuracy: 0.7990
# Epoch 50/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5466 - accuracy: 0.8062 - val_loss: 0.6408 - val_accuracy: 0.8041
# Epoch 51/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5524 - accuracy: 0.8069 - val_loss: 0.6529 - val_accuracy: 0.7981
# Epoch 52/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5407 - accuracy: 0.8079 - val_loss: 0.6826 - val_accuracy: 0.8002
# Epoch 53/100
# 26048/26048 [==============================] - 2s 78us/step - loss: 0.5568 - accuracy: 0.8075 - val_loss: 0.6664 - val_accuracy: 0.8015
# Epoch 54/100
# 26048/26048 [==============================] - 2s 68us/step - loss: 0.5610 - accuracy: 0.8098 - val_loss: 0.6852 - val_accuracy: 0.7973
# Epoch 55/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5736 - accuracy: 0.8062 - val_loss: 0.7084 - val_accuracy: 0.7972
# Epoch 56/100
# 26048/26048 [==============================] - 2s 75us/step - loss: 0.5730 - accuracy: 0.8062 - val_loss: 0.6846 - val_accuracy: 0.7940
# Epoch 57/100
# 26048/26048 [==============================] - 2s 68us/step - loss: 0.5629 - accuracy: 0.8057 - val_loss: 0.7103 - val_accuracy: 0.8004
# Epoch 58/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5703 - accuracy: 0.8066 - val_loss: 0.6535 - val_accuracy: 0.8045
# Epoch 59/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5781 - accuracy: 0.8066 - val_loss: 0.6913 - val_accuracy: 0.7955
# Epoch 60/100
# 26048/26048 [==============================] - 2s 73us/step - loss: 0.5696 - accuracy: 0.8052 - val_loss: 0.7781 - val_accuracy: 0.7963
# Epoch 61/100
# 26048/26048 [==============================] - 2s 76us/step - loss: 0.5751 - accuracy: 0.8058 - val_loss: 0.6941 - val_accuracy: 0.7967
# Epoch 62/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5704 - accuracy: 0.8068 - val_loss: 0.7082 - val_accuracy: 0.8007
# Epoch 63/100
# 26048/26048 [==============================] - 2s 74us/step - loss: 0.5752 - accuracy: 0.8053 - val_loss: 0.7472 - val_accuracy: 0.7987
# Epoch 64/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5735 - accuracy: 0.8059 - val_loss: 0.6783 - val_accuracy: 0.8004
# Epoch 65/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5730 - accuracy: 0.8066 - val_loss: 0.6925 - val_accuracy: 0.7998
# Epoch 66/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5724 - accuracy: 0.8067 - val_loss: 0.6729 - val_accuracy: 0.8016
# Epoch 67/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5779 - accuracy: 0.8056 - val_loss: 0.7513 - val_accuracy: 0.7944
# Epoch 68/100
# 26048/26048 [==============================] - 2s 68us/step - loss: 0.5839 - accuracy: 0.8058 - val_loss: 0.6940 - val_accuracy: 0.8015
# Epoch 69/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5729 - accuracy: 0.8056 - val_loss: 0.7083 - val_accuracy: 0.7952
# Epoch 70/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5761 - accuracy: 0.8060 - val_loss: 0.6700 - val_accuracy: 0.8009
# Epoch 71/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5702 - accuracy: 0.8056 - val_loss: 0.6964 - val_accuracy: 0.7973
# Epoch 72/100
#  - ETA: 0s - loss: 0.5702 - accuracy: 0.8081
# Epoch 73/100
# 26048/26048 [==============================] - 2s 68us/step - loss: 0.5694 - accuracy: 0.8058 - val_loss: 0.6740 - val_accuracy: 0.7910
# Epoch 74/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5686 - accuracy: 0.8068 - val_loss: 0.6890 - val_accuracy: 0.8030
# Epoch 75/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5655 - accuracy: 0.8070 - val_loss: 0.6695 - val_accuracy: 0.8053
# Epoch 76/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5719 - accuracy: 0.8060 - val_loss: 0.6776 - val_accuracy: 0.7920
# Epoch 77/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5688 - accuracy: 0.8069 - val_loss: 0.7844 - val_accuracy: 0.8024
# Epoch 78/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5619 - accuracy: 0.8061 - val_loss: 0.6579 - val_accuracy: 0.7999
# Epoch 79/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5638 - accuracy: 0.8054 - val_loss: 0.7004 - val_accuracy: 0.7989
# Epoch 80/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5743 - accuracy: 0.8037 - val_loss: 0.6628 - val_accuracy: 0.7995
# Epoch 81/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5934 - accuracy: 0.8033 - val_loss: 0.7010 - val_accuracy: 0.7975
# Epoch 82/100
# 26048/26048 [==============================] - 2s 68us/step - loss: 0.5720 - accuracy: 0.8059 - val_loss: 0.6947 - val_accuracy: 0.8007
# Epoch 83/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5838 - accuracy: 0.8053 - val_loss: 0.7042 - val_accuracy: 0.7990
# Epoch 84/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5688 - accuracy: 0.8069 - val_loss: 0.6708 - val_accuracy: 0.7981
# Epoch 85/100
# 26048/26048 [==============================] - 2s 67us/step - loss: 0.5669 - accuracy: 0.8051 - val_loss: 0.6929 - val_accuracy: 0.7996
# Epoch 86/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5766 - accuracy: 0.8054 - val_loss: 0.7132 - val_accuracy: 0.8004
# Epoch 87/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5822 - accuracy: 0.8042 - val_loss: 0.7207 - val_accuracy: 0.7932
# Epoch 88/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5728 - accuracy: 0.8035 - val_loss: 0.6744 - val_accuracy: 0.7986
# Epoch 89/100
# 26048/26048 [==============================] - 2s 71us/step - loss: 0.5588 - accuracy: 0.8054 - val_loss: 0.7285 - val_accuracy: 0.7844
# Epoch 90/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5661 - accuracy: 0.8037 - val_loss: 0.6869 - val_accuracy: 0.7794
# Epoch 91/100
# 26048/26048 [==============================] - 2s 72us/step - loss: 0.5694 - accuracy: 0.8070 - val_loss: 0.6965 - val_accuracy: 0.7959
# Epoch 92/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5741 - accuracy: 0.8040 - val_loss: 0.7089 - val_accuracy: 0.7973
# Epoch 93/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5635 - accuracy: 0.8031 - val_loss: 0.6625 - val_accuracy: 0.7993
# Epoch 94/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5548 - accuracy: 0.8066 - val_loss: 0.6939 - val_accuracy: 0.7953
# Epoch 95/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5565 - accuracy: 0.8056 - val_loss: 0.7008 - val_accuracy: 0.7998
# Epoch 96/100
# 26048/26048 [==============================] - 2s 69us/step - loss: 0.5611 - accuracy: 0.8061 - val_loss: 0.6450 - val_accuracy: 0.7950
# Epoch 97/100
# 26048/26048 [==============================] - 2s 70us/step - loss: 0.5600 - accuracy: 0.8082 - val_loss: 0.6773 - val_accuracy: 0.8032
# Epoch 98/100
# 26048/26048 [==============================] - 2s 68us/step - loss: 0.5581 - accuracy: 0.8079 - val_loss: 0.7029 - val_accuracy: 0.7982
# Epoch 99/100
# 26048/26048 [==============================] - 2s 68us/step - loss: 0.5550 - accuracy: 0.8065 - val_loss: 0.6558 - val_accuracy: 0.8006
# Epoch 100/100
# 26048/26048 [==============================] - 2s 67us/step - loss: 0.5461 - accuracy: 0.8066 - val_loss: 0.6968 - val_accuracy: 0.7950

# %%
# 根据过往记录调参

history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
# %matplotlib inline
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1,len(loss_values)+1)
plt.plot(epochs,loss_values,'bo',label='Training loss')
plt.plot(epochs,val_loss_values,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.clf()
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs,acc_values,'bo',label='Training acc')
plt.plot(epochs,val_acc_values,'b',label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()

# %%
# confusion_matrix
y_pred = model.predict_classes(x_test)
y_pred = y_pred.astype(int)
ann_confusion_matrix = confusion_matrix(y_test, y_pred)
accuracy_score(y_test, y_pred)
# Out:
# 0.8528960137583687

# %%
types = ['0', '1']
plot_confusion_matrix(ann_confusion_matrix, classes=types, normalize=False,
                      title='confusion matrix for ANN')
# Out:
# Confusion matrix, without normalization
# [[11623   812]
#  [ 1583  2263]]
